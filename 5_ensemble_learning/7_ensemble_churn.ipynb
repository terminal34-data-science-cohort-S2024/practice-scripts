# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler

# %%
churn_df = pd.read_csv('drive/MyDrive/Terminal34/WA_Fn-UseC_-Telco-Customer-Churn.csv')
churn_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ## EDA

# %%
sns.countplot(data=churn_df, x='gender')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(data=churn_df, x='SeniorCitizen')
# Out:
# <Axes: xlabel='SeniorCitizen', ylabel='count'>

# %%
sns.countplot(data=churn_df, x='Dependents')
# Out:
# <Axes: xlabel='Dependents', ylabel='count'>

# %%
sns.countplot(data=churn_df, x='InternetService', hue='Churn')
# Out:
# <Axes: xlabel='InternetService', ylabel='count'>

# %%
sns.histplot(data=churn_df, x='MonthlyCharges')
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='Count'>

# %%
sns.histplot(data=churn_df, x='Churn')
# Out:
# <Axes: xlabel='Churn', ylabel='Count'>

# %%
sns.histplot(data=churn_df, x='Contract')
# Out:
# <Axes: xlabel='Contract', ylabel='Count'>

# %%
sns.histplot(data=churn_df, x='Contract', hue='Churn')
# Out:
# <Axes: xlabel='Contract', ylabel='Count'>

# %%
sns.boxplot(data=churn_df, x='Churn', y='tenure')
# Out:
# <Axes: xlabel='Churn', ylabel='tenure'>

# %% [markdown]
# ## 4. Feature Engineering

# %%
churn_df_clean = churn_df.drop(['customerID'], axis=1)
churn_df_clean.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
churn_df_clean['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
churn_df_clean['gender']= churn_df_clean['gender'].map({'Female': 0, 'Male': 1})
churn_df_clean.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0       0              0     Yes         No       1           No
# 1       1              0      No         No      34          Yes
# 2       1              0      No         No       2          Yes
# 3       1              0      No         No      45           No
# 4       0              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
churn_df_clean.dtypes
# Out:
# gender                int64
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# this line will error out because of no-data
# churn_df_clean['TotalCharges'] = churn_df_clean['TotalCharges'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-f118ba275473> in <cell line: 1>()
# ----> 1 churn_df_clean['TotalCharges'] = churn_df_clean['TotalCharges'].astype('float')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6322         else:
#    6323             # else, only a single dtype is given
# -> 6324             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325             return self._constructor(new_data).__finalize__(self, method="astype")
#    6326
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     449             copy = False
#     450
# --> 451         return self.apply(
#     452             "astype",
#     453             dtype=dtype,
#
# ...

# %%
churn_df_clean['TotalCharges'].apply(lambda x : len(x.split(' ')) > 1).unique()
# Out:
# array([False,  True])

# %%
churn_df_clean['TotalCharges'] = pd.to_numeric(churn_df_clean.TotalCharges, errors='coerce')
churn_df_clean.isnull().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
churn_df_clean[np.isnan(churn_df_clean['TotalCharges'])]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488        0              0     Yes        Yes       0           No
# 753        1              0      No        Yes       0          Yes
# 936        0              0     Yes        Yes       0          Yes
# 1082       1              0     Yes        Yes       0          Yes
# 1340       0              0     Yes        Yes       0           No
# 3331       1              0     Yes        Yes       0          Yes
# 3826       1              0     Yes        Yes       0          Yes
# 4380       0              0     Yes        Yes       0          Yes
# 5218       1              0     Yes        Yes       0          Yes
# 6670       0              0     Yes        Yes       0          Yes
# 6754       1              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
churn_df_clean[churn_df_clean['tenure'] == 0].index
# Out:
# Index([488, 753, 936, 1082, 1340, 3331, 3826, 4380, 5218, 6670, 6754], dtype='int64')

# %%
churn_df_clean.drop(labels=churn_df_clean[churn_df_clean['tenure'] == 0].index, axis=0, inplace=True)
churn_df_clean[churn_df_clean['tenure'] == 0].index
# Out:
# Index([], dtype='int64')

# %%
def object_to_int(dataframe_series):
    if dataframe_series.dtype == 'object':
        dataframe_series = LabelEncoder().fit_transform(dataframe_series)
    return dataframe_series

# %%
# Convert object to integer
churn_df_clean = churn_df_clean.apply(lambda x: object_to_int(x))
churn_df_clean.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %% [markdown]
# ## Split Dataset

# %%
X = churn_df_clean.drop(["Churn"], axis=1)
y = churn_df_clean["Churn"]

# %%
X.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
scaler = StandardScaler()
num_cols = ['tenure', 'MonthlyCharges', 'TotalCharges']
X[num_cols] = scaler.fit_transform(X[num_cols])

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.20, random_state = 42)

# %%
X_train.shape, X_test.shape
# Out:
# ((5625, 19), (1407, 19))

# %% [markdown]
# ## Train Simple Model

# %%
rfr = RandomForestClassifier()

# %%
# Parameters for grid search
para = {
    "n_estimators": [100, 300, 1000],
    "max_depth": [2, 4],#, 6, 8],
    "min_samples_split": [2],#, 4, 6, 8],
    "min_samples_leaf": [2],#, 4, 6, 8],
    "random_state": [0],#, 42]
}

# Grid search object
grid = GridSearchCV(rfr, para, cv=5, n_jobs=-1, verbose=1)

# Fitting the grid search object
grid.fit(X_train, y_train)

# Best parameters
print(grid.best_params_)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# {'max_depth': 4, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 0}

# %%
model_rf = RandomForestClassifier(**grid.best_params_)
model_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=4, min_samples_leaf=2, random_state=0)

# %%
# Make predictions
prediction_test = model_rf.predict(X_test)
print(metrics.accuracy_score(y_test, prediction_test))
# Out:
# 0.7889125799573561
